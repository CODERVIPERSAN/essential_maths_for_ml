# %%
v1 = QQ^4
v1.random_element()

u = vector(QQ,[3,2,1/2,5/4])
print(u)


v2 = vector(QQ,[1,1,0,-1])
print(v2)
print(u in v1 ,v2 in v1)
# Out:
# (3, 2, 1/2, 5/4)
# (1, 1, 0, -1)
# True True

# %%
t = var('t')
p1 = plot(cos(2*t) + 2*cos(t), (t,0, 2*pi), rgbcolor=hue(0.3))
p2 = plot(4*cos(t) - cos(2*t), (t,0, 2*pi), rgbcolor=hue(0.6))
show(p1 + p2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
V = RR^3
a1 = vector(RR,[1,1,2])
a2 = vector(RR,[1,2,0])
a3 = vector(RR,[0,2,1])


V.linear_dependence([a1,a2,a3])
'linear independent'
a,b,c = var('a b c')

sol = solve([a+b==0,a+ 2*b + 2*c ==0,2*a + c ==0],a,b,c)
sol = solve([a+b==0,a+ 2*b + 2*c ==0,2*a + c ==0],a,b,c)
# V.lineaprir_dependence([a1,a2,a3])
print(sol)
V.linear_dependence([a1,a2,a3])
'linear_independent'
# Out:
# [
# [a == 0, b == 0, c == 0]
# ]
# 'linear_independent'

# %%
x,y = var('x y')

eq(x) = (2/-3)*x^2

plot(eq(x),x,-200,200)

for i in range(-1000,1000):
    # print(i)
    if(eq(i)==0):
        print(i,eq(i))
# Out:
# 0 0
